# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("/data3fast/users/group02/videos/tracks/HtfX_sL7OKk/face_frames.npz")

# %%
# Lista todas las claves del archivo para saber qué arrays contiene
keys = list(data.keys())
print("Claves disponibles en el archivo NPZ:", keys)

# Asumiendo que queremos acceder al primer array y mostrar el primer frame
# Reemplaza 'clave_del_array' por la clave real del primer array que quieras visualizar
first_key = keys[0]  # Cambia esto si necesitas una clave específica
frame = data[first_key]  # Asumiendo que el frame que queremos es el primero
print(frame.shape)
# Muestra el frame
plt.imshow(frame[34].astype(np.uint8))
plt.show()
# Out:
# Claves disponibles en el archivo NPZ: ['face_frames']
# (124, 258, 258, 3)
